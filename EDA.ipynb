# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data/wrangled_data.csv')
df2 = df.groupby('capture_site').sum('capture_number').reset_index()
df2['capture_number'].sum()
# Out:
# 78744

# %%
df2['Est. Capture Probability (%)'] = df2['capture_number'].div(787.44)

# %%
df2['cs_probability'].sum()
df2['Capture Site'] = df2['capture_site']
df2
# Out:
#     capture_site  Unnamed: 0.1  Unnamed: 0  tag_2     ccl_cm         ccw_cm
# 0              0          4465        4465     27    3952.29    3757.840000  \
# 1              1        389363      389363    219   33339.14   30959.183904
# 2              2        519448      519448    222   18435.02   17215.473904
# 3              3        470340      470340     56   13327.94   12542.697808
# 4              4       1117350     1117350    120   23170.95   21909.423904
# 5              5       2173187     2173187    230   32091.61   30462.163904
# 6              6        667393      667393     71    8935.71    8422.150000
# 7              7       8463339     8463339    740   74737.70   69153.127808
# 8              8       5486481     5486481    221   41662.92   39084.297808
# 9              9       1590587     1590587     78    9719.73    9003.940000
# 10            10        187833      187833      6    1375.05    1287.570000
# ...

# %%
sns.barplot(data=df2, x=df2['Capture Site'], y=df2['Est. Capture Probability (%)'])
# Out:
# <Axes: xlabel='Capture Site', ylabel='Est. Capture Probability (%)'>
